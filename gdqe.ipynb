# %%
import numpy as np

# %%
a = float(input("Enter the coefficient (a): "))
b = float(input("Enter the coefficient (b): "))
c = float(input("Enter the coefficient (c): "))
d = float(input("Enter the coefficient (d): "))
# Out:
# Enter the coefficient (a):  5
# Enter the coefficient (b):  3
# Enter the coefficient (c):  2
# Enter the coefficient (d):  4

# %%
x=np.random.rand()
learning_rate=0.01
epochs=100

# %%
for epoch in range (epochs):
     value=a*x**3+b*x**2+d*x+c
     gradient= 3*a *x**2 + 2*b*x+c

    
     if gradient < -1:
        gradient =0
        x -=  learning_rate *gradient

# %%
print(f"The Equation is: {a}x^3 + {b}x^2 + {d}x + {c}")
print(f"The solution for x is approximately : {x}")
# Out:
# The Equation is: 5.0x^3 + 3.0x^2 + 4.0x + 2.0
# The solution for x is approximately : 0.030311011143172695
